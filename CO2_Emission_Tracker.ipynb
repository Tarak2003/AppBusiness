# %% [markdown]
# <a href="https://colab.research.google.com/github/Tarak2003/AppBusiness/blob/main/CO2_Emission_Tracker.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import files

# %%
# Upload a file from your local machine
uploaded = files.upload()

# Get the file name
file_name = list(uploaded.keys())[0]

print(f"Uploaded file: {file_name}")

steel_companies_list = pd.read_excel(file_name)
# Out:
#      <input type="file" id="files-41a4433d-745d-45a7-b146-a5566c499979" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-41a4433d-745d-45a7-b146-a5566c499979">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Upload a file from your local machine
uploaded = files.upload()

# Get the file name
file_name = list(uploaded.keys())[0]

# Print the uploaded file name
print(f"Uploaded file: {file_name}")

aluminium_companies_list = pd.read_excel(file_name)
# Out:
#      <input type="file" id="files-f5bd0a6d-6aa9-41e1-aaa0-5fadc791170e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f5bd0a6d-6aa9-41e1-aaa0-5fadc791170e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Upload a file from your local machine
uploaded = files.upload()

# Get the file name
file_name = list(uploaded.keys())[0]

# Print the uploaded file name
print(f"Uploaded file: {file_name}")

copper_companies_list = pd.read_excel(file_name)
# Out:
#      <input type="file" id="files-b39450c4-5291-4e79-8943-32a4446d6e19" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b39450c4-5291-4e79-8943-32a4446d6e19">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Upload a file from your local machine
uploaded = files.upload()

# Get the file name
file_name = list(uploaded.keys())[0]

# Print the uploaded file name
print(f"Uploaded file: {file_name}")

windows_companies_list = pd.read_excel(file_name)
# Out:
#      <input type="file" id="files-b8d28b7f-6106-41d8-b720-549b14afe63a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b8d28b7f-6106-41d8-b720-549b14afe63a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Upload a file from your local machine
uploaded = files.upload()

# Get the file name
file_name = list(uploaded.keys())[0]

# Print the uploaded file name
print(f"Uploaded file: {file_name}")

rubber_companies_list = pd.read_excel(file_name)
# Out:
#      <input type="file" id="files-65ef4803-5d20-47b7-a379-8f3f609f68f6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-65ef4803-5d20-47b7-a379-8f3f609f68f6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Upload a file from your local machine
uploaded = files.upload()

# Get the file name
file_name = list(uploaded.keys())[0]

# Print the uploaded file name
print(f"Uploaded file: {file_name}")

plastic_companies_list = pd.read_excel(file_name)
# Out:
#      <input type="file" id="files-e72dea0e-d2d8-4c2f-9afd-8f48f8aecbba" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e72dea0e-d2d8-4c2f-9afd-8f48f8aecbba">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Upload a file from your local machine
uploaded = files.upload()

# Get the file name
file_name = list(uploaded.keys())[0]

# Print the uploaded file name
print(f"Uploaded file: {file_name}")

polymer_companies_list = pd.read_excel(file_name)
# Out:
#      <input type="file" id="files-831955ee-b62a-4c14-bcee-fe824b9a429e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-831955ee-b62a-4c14-bcee-fe824b9a429e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Upload a file from your local machine
uploaded = files.upload()

# Get the file name
file_name = list(uploaded.keys())[0]

# Print the uploaded file name
print(f"Uploaded file: {file_name}")

electronics_companies_list = pd.read_excel(file_name)
# Out:
#      <input type="file" id="files-9f4b9861-c0b0-42e9-b746-2aa86a9e9137" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9f4b9861-c0b0-42e9-b746-2aa86a9e9137">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Upload a file from your local machine
uploaded = files.upload()

# Get the file name
file_name = list(uploaded.keys())[0]

# Print the uploaded file name
print(f"Uploaded file: {file_name}")

textile_companies_list = pd.read_excel(file_name)
# Out:
#      <input type="file" id="files-24106ad5-ff42-4fc3-8656-8baeb3d5916d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-24106ad5-ff42-4fc3-8656-8baeb3d5916d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Upload a file from your local machine
uploaded = files.upload()

# Get the file name
file_name = list(uploaded.keys())[0]

# Print the uploaded file name
print(f"Uploaded file: {file_name}")

paint_companies_list = pd.read_excel(file_name)
# Out:
#      <input type="file" id="files-85fb468f-21bf-4b48-a3a9-3a8b9a31c405" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-85fb468f-21bf-4b48-a3a9-3a8b9a31c405">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Upload a file from your local machine
uploaded = files.upload()

# Get the file name
file_name = list(uploaded.keys())[0]

# Print the uploaded file name
print(f"Uploaded file: {file_name}")

material_companies_list = pd.read_excel(file_name)
# Out:
#      <input type="file" id="files-93072d61-f963-4329-bd9e-49e707d7f979" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-93072d61-f963-4329-bd9e-49e707d7f979">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Upload a file from your local machine
uploaded = files.upload()

# Get the file name
file_name = list(uploaded.keys())[0]

# Print the uploaded file name
print(f"Uploaded file: {file_name}")

bolts_companies_list = pd.read_excel(file_name)
# Out:
#      <input type="file" id="files-72f47b29-8b5c-4a84-b5e3-24779976a74d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-72f47b29-8b5c-4a84-b5e3-24779976a74d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Upload a file from your local machine
uploaded = files.upload()

# Get the file name
file_name = list(uploaded.keys())[0]

# Print the uploaded file name
print(f"Uploaded file: {file_name}")

transportation_companies_list = pd.read_excel(file_name)
# Out:
#      <input type="file" id="files-3497ef7c-bc4f-4216-8eca-693e3c2c12f8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3497ef7c-bc4f-4216-8eca-693e3c2c12f8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Upload a file from your local machine
uploaded = files.upload()

# Get the file name
file_name = list(uploaded.keys())[0]

# Print the uploaded file name
print(f"Uploaded file: {file_name}")

manufacturing_car_list = pd.read_excel(file_name)
# Out:
#      <input type="file" id="files-b595029b-35db-4f40-9a66-2bd294b314e2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b595029b-35db-4f40-9a66-2bd294b314e2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
carbon_tax_per_metric_ton = 49 #We assume the Carbon Tax to be $49 per metric Ton
waste_tax_per_kg = 2 #We assume the waste tax to be $2 per kg

# %%
steel_co2_emissions_column = steel_companies_list['CO2Emissions(MetricTons)']
aluminium_co2_emission_column = aluminium_companies_list['CO2Emissions(MetricTons)']
copper_co2_emission_column = copper_companies_list['CO2Emissions(MetricTons)']
rubber_co2_emission_column = rubber_companies_list['CO2Emissions(MetricTons)']
plastic_co2_emission_column = plastic_companies_list['CO2Emissions(MetricTons)']
polymer_co2_emission_column = polymer_companies_list['CO2Emissions(MetricTons)']
bolts_co2_emission_column = bolts_companies_list['CO2Emissions(MetricTons)']
material_co2_emission_column = material_companies_list['CO2Emissions(MetricTons)']
windows_co2_emisson_column = windows_companies_list['CO2Emissions(MetricTons)']
textile_co2_emission_column = textile_companies_list['CO2Emissions(MetricTons)']
paint_co2_emission_column = paint_companies_list['CO2Emissions(MetricTons)']
electronics_co2_emission_column = electronics_companies_list['CO2Emissions(MetricTons)']

manufacturing_co2_emission_column = manufacturing_car_list['CO2Emissions(MetricTons)']

# %%
steel_co2_tax_total = steel_companies_list['CO2Emissions(MetricTons)'] * carbon_tax_per_metric_ton
aluminium_co2_tax_total = aluminium_companies_list['CO2Emissions(MetricTons)'] * carbon_tax_per_metric_ton
copper_co2_tax_total = copper_companies_list['CO2Emissions(MetricTons)'] * carbon_tax_per_metric_ton
rubber_co2_tax_total = rubber_companies_list['CO2Emissions(MetricTons)'] * carbon_tax_per_metric_ton
plastic_co2_tax_total = plastic_companies_list['CO2Emissions(MetricTons)'] * carbon_tax_per_metric_ton
polymer_co2_tax_total = polymer_companies_list['CO2Emissions(MetricTons)'] * carbon_tax_per_metric_ton
bolts_co2_tax_total = bolts_companies_list['CO2Emissions(MetricTons)'] * carbon_tax_per_metric_ton
material_co2_tax_total = material_companies_list['CO2Emissions(MetricTons)'] * carbon_tax_per_metric_ton
windows_co2_tax_total = windows_companies_list['CO2Emissions(MetricTons)'] * carbon_tax_per_metric_ton
textile_co2_tax_total = textile_companies_list['CO2Emissions(MetricTons)'] * carbon_tax_per_metric_ton
paint_co2_tax_total = paint_companies_list['CO2Emissions(MetricTons)'] * carbon_tax_per_metric_ton
electronics_co2_tax_total = electronics_companies_list['CO2Emissions(MetricTons)'] * carbon_tax_per_metric_ton

manufacturing_co2_tax_total = manufacturing_car_list['CO2Emissions(MetricTons)'] * carbon_tax_per_metric_ton

# %%
steel_waste_emissions_column = steel_companies_list['WasteGeneration(Tons in kg)']
aluminium_waste_emission_column = aluminium_companies_list['WasteGeneration(PerTon in kg)']
copper_waste_emission_column = copper_companies_list['WasteGeneration(PerTon in kg)']
rubber_waste_emission_column = rubber_companies_list['WasteGeneration(Tons in kg)']
plastic_waste_emission_column = plastic_companies_list['WasteGeneration(Tons in kg)']
polymer_waste_emission_column = polymer_companies_list['WasteGeneration(PerTon in kg)']
bolts_waste_emission_column = bolts_companies_list['WasteGeneration(PerTon in kg)']
material_waste_emission_column = material_companies_list['WasteGeneration(PerTon in kg)']
windows_waste_emisson_column = windows_companies_list['WasteGeneration(Tons in kg)']
textile_waste_emission_column = textile_companies_list['WasteGeneration(PerTon in kg)']
paint_waste_emission_column = paint_companies_list['WasteGeneration(PerTon in kg)']
electronics_waste_emission_column = electronics_companies_list['WasteGeneration(PerTon in kg)']

manufacturing_waste_emission_column = manufacturing_car_list['WasteGeneration(PerTon in kg)']

# %%
steel_waste_tax_total = steel_companies_list['WasteGeneration(Tons in kg)'] * waste_tax_per_kg
aluminium_waste_tax_total = aluminium_companies_list['WasteGeneration(PerTon in kg)'] * waste_tax_per_kg
copper_waste_tax_total = copper_companies_list['WasteGeneration(PerTon in kg)'] * waste_tax_per_kg
rubber_waste_tax_total = rubber_companies_list['WasteGeneration(Tons in kg)'] * waste_tax_per_kg
plastic_waste_tax_total = plastic_companies_list['WasteGeneration(Tons in kg)'] * waste_tax_per_kg
polymer_waste_tax_total = polymer_companies_list['WasteGeneration(PerTon in kg)'] * waste_tax_per_kg
bolts_waste_tax_total = bolts_companies_list['WasteGeneration(PerTon in kg)'] * waste_tax_per_kg
material_waste_tax_total = material_companies_list['WasteGeneration(PerTon in kg)'] * waste_tax_per_kg
windows_waste_tax_total = windows_companies_list['WasteGeneration(Tons in kg)'] * waste_tax_per_kg
textile_waste_tax_total = textile_companies_list['WasteGeneration(PerTon in kg)'] * waste_tax_per_kg
paint_waste_tax_total = paint_companies_list['WasteGeneration(PerTon in kg)'] * waste_tax_per_kg
electronics_waste_tax_total = electronics_companies_list['WasteGeneration(PerTon in kg)'] * waste_tax_per_kg

manufacturing_waste_tax_total = manufacturing_car_list['WasteGeneration(PerTon in kg)'] * waste_tax_per_kg

# %%
steel_per_ton_cost = steel_companies_list['CostOfSteel(USDPerTon)']
aluminium_per_ton_cost = aluminium_companies_list['CostOfAluminium(USDPerTon)']
copper_per_ton_cost = copper_companies_list['CostOfCopper(USDPerTon)']
rubber_per_ton_cost = rubber_companies_list['CostOfRubber(USDPerTon)']
plastic_per_ton_cost = plastic_companies_list['CostOfPlastic(USDPerTon)']
polymer_per_ton_cost = polymer_companies_list['CostOfPolymers(USDPerTon)']
bolts_per_ton_cost = bolts_companies_list['CostOfBolts(USDPerTon)']
material_per_ton_cost = material_companies_list['CostOfMaterial(USDPerTon)']
windows_per_ton_cost = windows_companies_list['CostOfWindows(USDPerTon)']
textile_per_ton_cost = textile_companies_list['CostOfTextile(USDPerTon)']
paint_per_ton_cost = paint_companies_list['CostOfPaint(USDPerTon)']
electronics_per_ton_cost = electronics_companies_list['CostOfElectronics(USDPerTon)']

manufacturing_per_car_cost = manufacturing_car_list['CostOfAssembling(USDPerCar)']

# %%
transportation_companies_list['CO2 Emission (MetricTon/30km)'] = transportation_companies_list['CO2 Emission (kg/30km)']/1000

# %%
transportation_carbon_tax_per_company_per_km = transportation_companies_list['CO2 Emission (MetricTon/30km)']/30 * carbon_tax_per_metric_ton

# %%
#Steel
steel_transportation_distance = steel_companies_list['Distance']
steel_transportation_costs = []

for distance_value in steel_transportation_distance:
    if distance_value < 50:
      steel_cost = distance_value * transportation_companies_list['Cost of Transportation (USD Per Km) below 50 km'].min()
    elif distance_value > 50 and distance_value < 400:
      steel_cost = distance_value * transportation_companies_list['Cost of Transportation (USD Per Km) below 400 km'].min()
    else:
      steel_cost = distance_value * transportation_companies_list['Cost of Transportation (USD Per Km) above 400 km'].min()

    steel_transportation_costs.append(steel_cost)

steel_companies_list['TransportationCost'] = steel_transportation_costs

#Aluminium
aluminium_transportation_distance = aluminium_companies_list['Distance']
aluminium_transportation_costs = []

for distance_value in aluminium_transportation_distance:
    if distance_value < 50:
      aluminium_cost = distance_value * transportation_companies_list['Cost of Transportation (USD Per Km) below 50 km'].min()
    elif distance_value > 50 and distance_value < 400:
      aluminium_cost = distance_value * transportation_companies_list['Cost of Transportation (USD Per Km) below 400 km'].min()
    else:
      aluminium_cost = distance_value * transportation_companies_list['Cost of Transportation (USD Per Km) above 400 km'].min()

    aluminium_transportation_costs.append(aluminium_cost)

aluminium_companies_list['TransportationCost'] = aluminium_transportation_costs

#Copper
copper_transportation_distance = copper_companies_list['Distance']
copper_transportation_costs = []

for distance_value in copper_transportation_distance:
    if distance_value < 50:
      copper_cost = distance_value * transportation_companies_list['Cost of Transportation (USD Per Km) below 50 km'].min()
    elif distance_value > 50 and distance_value < 400:
      copper_cost = distance_value * transportation_companies_list['Cost of Transportation (USD Per Km) below 400 km'].min()
    else:
      copper_cost = distance_value * transportation_companies_list['Cost of Transportation (USD Per Km) above 400 km'].min()

    copper_transportation_costs.append(copper_cost)

copper_companies_list['TransportationCost'] = copper_transportation_costs

#Rubber
rubber_transportation_distance = rubber_companies_list['Distance']
rubber_transportation_costs = []

for distance_value in rubber_transportation_distance:
    if distance_value < 50:
      rubber_cost = distance_value * transportation_companies_list['Cost of Transportation (USD Per Km) below 50 km'].min()
    elif distance_value > 50 and distance_value < 400:
      rubber_cost = distance_value * transportation_companies_list['Cost of Transportation (USD Per Km) below 400 km'].min()
    else:
      rubber_cost = distance_value * transportation_companies_list['Cost of Transportation (USD Per Km) above 400 km'].min()

    rubber_transportation_costs.append(rubber_cost)

rubber_companies_list['TransportationCost'] = rubber_transportation_costs

#Plastic
plastic_transportation_distance = plastic_companies_list['Distance']
plastic_transportation_costs = []

for distance_value in plastic_transportation_distance:
    if distance_value < 50:
      plastic_cost = distance_value * transportation_companies_list['Cost of Transportation (USD Per Km) below 50 km'].min()
    elif distance_value > 50 and distance_value < 400:
      plastic_cost = distance_value * transportation_companies_list['Cost of Transportation (USD Per Km) below 400 km'].min()
    else:
      plastic_cost = distance_value * transportation_companies_list['Cost of Transportation (USD Per Km) above 400 km'].min()

    plastic_transportation_costs.append(plastic_cost)

plastic_companies_list['TransportationCost'] = plastic_transportation_costs

#Polymer
polymer_transportation_distance = polymer_companies_list['Distance']
polymer_transportation_costs = []

for distance_value in polymer_transportation_distance:
    if distance_value < 50:
      polymer_cost = distance_value * transportation_companies_list['Cost of Transportation (USD Per Km) below 50 km'].min()
    elif distance_value > 50 and distance_value < 400:
      polymer_cost = distance_value * transportation_companies_list['Cost of Transportation (USD Per Km) below 400 km'].min()
    else:
      polymer_cost = distance_value * transportation_companies_list['Cost of Transportation (USD Per Km) above 400 km'].min()

    polymer_transportation_costs.append(polymer_cost)

polymer_companies_list['TransportationCost'] = polymer_transportation_costs

#Bolts
bolts_transportation_distance = bolts_companies_list['Distance']
bolts_transportation_costs = []

for distance_value in bolts_transportation_distance:
    if distance_value < 50:
      bolts_cost = distance_value * transportation_companies_list['Cost of Transportation (USD Per Km) below 50 km'].min()
    elif distance_value > 50 and distance_value < 400:
      bolts_cost = distance_value * transportation_companies_list['Cost of Transportation (USD Per Km) below 400 km'].min()
    else:
      bolts_cost = distance_value * transportation_companies_list['Cost of Transportation (USD Per Km) above 400 km'].min()

    bolts_transportation_costs.append(bolts_cost)

bolts_companies_list['TransportationCost'] = bolts_transportation_costs

#Material
material_transportation_distance = material_companies_list['Distance']
material_transportation_costs = []

for distance_value in material_transportation_distance:
    if distance_value < 50:
      material_cost = distance_value * transportation_companies_list['Cost of Transportation (USD Per Km) below 50 km'].min()
    elif distance_value > 50 and distance_value < 400:
      material_cost = distance_value * transportation_companies_list['Cost of Transportation (USD Per Km) below 400 km'].min()
    else:
      material_cost = distance_value * transportation_companies_list['Cost of Transportation (USD Per Km) above 400 km'].min()

    material_transportation_costs.append(material_cost)

material_companies_list['TransportationCost'] = material_transportation_costs

#Windows
windows_transportation_distance = windows_companies_list['Distance']
windows_transportation_costs = []

for distance_value in windows_transportation_distance:
    if distance_value < 50:
      windows_cost = distance_value * transportation_companies_list['Cost of Transportation (USD Per Km) below 50 km'].min()
    elif distance_value > 50 and distance_value < 400:
      windows_cost = distance_value * transportation_companies_list['Cost of Transportation (USD Per Km) below 400 km'].min()
    else:
      windows_cost = distance_value * transportation_companies_list['Cost of Transportation (USD Per Km) above 400 km'].min()

    windows_transportation_costs.append(windows_cost)

windows_companies_list['TransportationCost'] = windows_transportation_costs

#Textile
textile_transportation_distance = textile_companies_list['Distance']
textile_transportation_costs = []

for distance_value in textile_transportation_distance:
    if distance_value < 50:
      textile_cost = distance_value * transportation_companies_list['Cost of Transportation (USD Per Km) below 50 km'].min()
    elif distance_value > 50 and distance_value < 400:
      textile_cost = distance_value * transportation_companies_list['Cost of Transportation (USD Per Km) below 400 km'].min()
    else:
      textile_cost = distance_value * transportation_companies_list['Cost of Transportation (USD Per Km) above 400 km'].min()

    textile_transportation_costs.append(textile_cost)

textile_companies_list['TransportationCost'] = textile_transportation_costs

#Paint
paint_transportation_distance = paint_companies_list['Distance']
paint_transportation_costs = []

for distance_value in paint_transportation_distance:
    if distance_value < 50:
      paint_cost = distance_value * transportation_companies_list['Cost of Transportation (USD Per Km) below 50 km'].min()
    elif distance_value > 50 and distance_value < 400:
      paint_cost = distance_value * transportation_companies_list['Cost of Transportation (USD Per Km) below 400 km'].min()
    else:
      paint_cost = distance_value * transportation_companies_list['Cost of Transportation (USD Per Km) above 400 km'].min()

    paint_transportation_costs.append(paint_cost)

paint_companies_list['TransportationCost'] = paint_transportation_costs

#Electronics
electronics_transportation_distance = electronics_companies_list['Distance']
electronics_transportation_costs = []

for distance_value in electronics_transportation_distance:
    if distance_value < 50:
      electronics_cost = distance_value * transportation_companies_list['Cost of Transportation (USD Per Km) below 50 km'].min()
    elif distance_value > 50 and distance_value < 400:
      electronics_cost = distance_value * transportation_companies_list['Cost of Transportation (USD Per Km) below 400 km'].min()
    else:
      electronics_cost = distance_value * transportation_companies_list['Cost of Transportation (USD Per Km) above 400 km'].min()

    electronics_transportation_costs.append(electronics_cost)

electronics_companies_list['TransportationCost'] = electronics_transportation_costs

# %%
#Steel
steel_sums = steel_companies_list['CO2Emissions(MetricTons)'] * carbon_tax_per_metric_ton + \
              steel_companies_list['WasteGeneration(Tons in kg)'] * waste_tax_per_kg + \
              steel_companies_list['CostOfSteel(USDPerTon)'] + \
              steel_companies_list['TransportationCost']

#Aluminium
aluminium_sums = aluminium_companies_list['CO2Emissions(MetricTons)'] * carbon_tax_per_metric_ton + \
              aluminium_companies_list['WasteGeneration(PerTon in kg)'] * waste_tax_per_kg + \
              aluminium_companies_list['CostOfAluminium(USDPerTon)'] + \
              aluminium_companies_list['TransportationCost']

#Copper
copper_sums = copper_companies_list['CO2Emissions(MetricTons)'] * carbon_tax_per_metric_ton + \
              copper_companies_list['WasteGeneration(PerTon in kg)'] * waste_tax_per_kg + \
              copper_companies_list['CostOfCopper(USDPerTon)'] + \
              copper_companies_list['TransportationCost']

#Rubber
rubber_sums = rubber_companies_list['CO2Emissions(MetricTons)'] * carbon_tax_per_metric_ton + \
              rubber_companies_list['WasteGeneration(Tons in kg)'] * waste_tax_per_kg + \
              rubber_companies_list['CostOfRubber(USDPerTon)'] + \
              rubber_companies_list['TransportationCost']

#Plastic
plastic_sums = plastic_companies_list['CO2Emissions(MetricTons)'] * carbon_tax_per_metric_ton + \
              plastic_companies_list['WasteGeneration(Tons in kg)'] * waste_tax_per_kg + \
              plastic_companies_list['CostOfPlastic(USDPerTon)'] + \
              plastic_companies_list['TransportationCost']

#Polymer
polymer_sums = polymer_companies_list['CO2Emissions(MetricTons)'] * carbon_tax_per_metric_ton + \
              polymer_companies_list['WasteGeneration(PerTon in kg)'] * waste_tax_per_kg + \
              polymer_companies_list['CostOfPolymers(USDPerTon)'] + \
              polymer_companies_list['TransportationCost']

#Bolts
bolts_sums = bolts_companies_list['CO2Emissions(MetricTons)'] * carbon_tax_per_metric_ton + \
              bolts_companies_list['WasteGeneration(PerTon in kg)'] * waste_tax_per_kg + \
              bolts_companies_list['CostOfBolts(USDPerTon)'] + \
              bolts_companies_list['TransportationCost']

#Material
material_sums = material_companies_list['CO2Emissions(MetricTons)'] * carbon_tax_per_metric_ton + \
              material_companies_list['WasteGeneration(PerTon in kg)'] * waste_tax_per_kg + \
              material_companies_list['CostOfMaterial(USDPerTon)'] + \
              material_companies_list['TransportationCost']

#Windows
windows_sums = windows_companies_list['CO2Emissions(MetricTons)'] * carbon_tax_per_metric_ton + \
              windows_companies_list['WasteGeneration(Tons in kg)'] * waste_tax_per_kg + \
              windows_companies_list['CostOfWindows(USDPerTon)'] + \
              windows_companies_list['TransportationCost']

#Textile
textile_sums = textile_companies_list['CO2Emissions(MetricTons)'] * carbon_tax_per_metric_ton + \
              textile_companies_list['WasteGeneration(PerTon in kg)'] * waste_tax_per_kg + \
              textile_companies_list['CostOfTextile(USDPerTon)'] + \
              textile_companies_list['TransportationCost']

#Paint
paint_sums = paint_companies_list['CO2Emissions(MetricTons)'] * carbon_tax_per_metric_ton + \
              paint_companies_list['WasteGeneration(PerTon in kg)'] * waste_tax_per_kg + \
              paint_companies_list['CostOfPaint(USDPerTon)'] + \
              paint_companies_list['TransportationCost']

#Electronics
electronics_sums = electronics_companies_list['CO2Emissions(MetricTons)'] * carbon_tax_per_metric_ton + \
              electronics_companies_list['WasteGeneration(PerTon in kg)'] * waste_tax_per_kg + \
              electronics_companies_list['CostOfElectronics(USDPerTon)'] + \
              electronics_companies_list['TransportationCost']

# %%
steel_companies_list['TotalSum'] = steel_sums
aluminium_companies_list['TotalSum'] = aluminium_sums
copper_companies_list['TotalSum'] = copper_sums
rubber_companies_list['TotalSum'] = rubber_sums
plastic_companies_list['TotalSum'] = plastic_sums
polymer_companies_list['TotalSum'] = polymer_sums
bolts_companies_list['TotalSum'] = bolts_sums
material_companies_list['TotalSum'] = material_sums
windows_companies_list['TotalSum'] = windows_sums
textile_companies_list['TotalSum'] = textile_sums
paint_companies_list['TotalSum'] = paint_sums
electronics_companies_list['TotalSum'] = electronics_sums

# %%
min_steel_price_company = steel_companies_list.loc[steel_companies_list['TotalSum'].idxmin()]
min_aluminium_price_company = aluminium_companies_list.loc[aluminium_companies_list['TotalSum'].idxmin()]
min_copper_price_company = copper_companies_list.loc[copper_companies_list['TotalSum'].idxmin()]
min_rubber_price_company = rubber_companies_list.loc[rubber_companies_list['TotalSum'].idxmin()]
min_plastic_price_company = plastic_companies_list.loc[plastic_companies_list['TotalSum'].idxmin()]
min_polymer_price_company = polymer_companies_list.loc[polymer_companies_list['TotalSum'].idxmin()]
min_bolts_price_company = bolts_companies_list.loc[bolts_companies_list['TotalSum'].idxmin()]
min_material_price_company = material_companies_list.loc[material_companies_list['TotalSum'].idxmin()]
min_windows_price_company = windows_companies_list.loc[windows_companies_list['TotalSum'].idxmin()]
min_textile_price_company = textile_companies_list.loc[textile_companies_list['TotalSum'].idxmin()]
min_paint_price_company = paint_companies_list.loc[paint_companies_list['TotalSum'].idxmin()]
min_electronics_price_company = electronics_companies_list.loc[electronics_companies_list['TotalSum'].idxmin()]

# %%
print("Company that supply items for least cost:")
print('')
print("Company which supply the steel for least cost:")
print(min_steel_price_company)
print('')
print("Company which supply the aluminium for least cost:")
print(min_aluminium_price_company)
print('')
print("Company which supply the copper for least cost:")
print(min_copper_price_company)
print('')
print("Company which supply the rubber for least cost:")
print(min_rubber_price_company)
print('')
print("Company which supply the plastic for least cost:")
print(min_plastic_price_company)
print('')
print("Company which supply the polymer for least cost:")
print(min_polymer_price_company)
print('')
print("Company which supply the bolts for least cost:")
print(min_bolts_price_company)
print('')
print("Company which supply the material for least cost:")
print(min_material_price_company)
print('')
print("Company which supply the windows for least cost:")
print(min_windows_price_company)
print('')
print("Company which supply the textile for least cost:")
print(min_textile_price_company)
print('')
print("Company which supply the paint for least cost:")
print(min_paint_price_company)
print('')
print("Company which supply the electronics for least cost:")
print(min_electronics_price_company)
# Out:
# Company that supply items for least cost:
#
# Company which supply the steel for least cost:
# Company ID                                               3
# Company Name                   Sustainable Steel Solutions
# Location                                         Bangalore
# EnergyUsage(MegawattHours)                          180000
# EnergySource                                         Solar
# WasteGeneration(Tons in kg)                             33
# CO2Emissions(MetricTons)                               1.2
# CostOfSteel(USDPerTon)                                 850
# Distance                                              12.0
# TransportationCost                                    19.2
# TotalSum                                             994.0
# Name: 2, dtype: object
#
# Company which supply the aluminium for least cost:
# Company ID                                              14
# Company Name                     GoldenGate Alloys
# ...

# %%
heatmap_data = steel_companies_list[['Company Name', 'CO2Emissions(MetricTons)']].set_index('Company Name')

plt.figure(figsize=(12, 6))
sns.heatmap(heatmap_data, annot=True, cmap='Reds', fmt='.2f', linewidths=.5)
plt.title('CO2 Emissions Heatmap for Steel Companies')
plt.show()

# %%
heatmap_data = copper_companies_list[['Company Name', 'CO2Emissions(MetricTons)']].set_index('Company Name')

plt.figure(figsize=(12, 6))
sns.heatmap(heatmap_data, annot=True, cmap='Reds', fmt='.2f', linewidths=.5)
plt.title('CO2 Emissions Heatmap for Copper Companies')
plt.show()

# %%
heatmap_data = aluminium_companies_list[['Company Name', 'CO2Emissions(MetricTons)']].set_index('Company Name')

plt.figure(figsize=(12, 6))
sns.heatmap(heatmap_data, annot=True, cmap='Reds', fmt='.2f', linewidths=.5)
plt.title('CO2 Emissions Heatmap for Aluminium Companies')
plt.show()

# %%
heatmap_data = rubber_companies_list[['Company Name', 'CO2Emissions(MetricTons)']].set_index('Company Name')

plt.figure(figsize=(12, 6))
sns.heatmap(heatmap_data, annot=True, cmap='Reds', fmt='.2f', linewidths=.5)
plt.title('CO2 Emissions Heatmap for Rubber Companies')
plt.show()

# %%
heatmap_data = plastic_companies_list[['Company Name', 'CO2Emissions(MetricTons)']].set_index('Company Name')

plt.figure(figsize=(12, 6))
sns.heatmap(heatmap_data, annot=True, cmap='Reds', fmt='.2f', linewidths=.5)
plt.title('CO2 Emissions Heatmap for Plastic Companies')
plt.show()

# %%
heatmap_data = polymer_companies_list[['Company Name', 'CO2Emissions(MetricTons)']].set_index('Company Name')

plt.figure(figsize=(12, 6))
sns.heatmap(heatmap_data, annot=True, cmap='Reds', fmt='.2f', linewidths=.5)
plt.title('CO2 Emissions Heatmap for Polymer Companies')
plt.show()

# %%
heatmap_data = bolts_companies_list[['Company Name', 'CO2Emissions(MetricTons)']].set_index('Company Name')

plt.figure(figsize=(12, 6))
sns.heatmap(heatmap_data, annot=True, cmap='Reds', fmt='.2f', linewidths=.5)
plt.title('CO2 Emissions Heatmap for Bolts Companies')
plt.show()

# %%
heatmap_data = material_companies_list[['Company Name', 'CO2Emissions(MetricTons)']].set_index('Company Name')

plt.figure(figsize=(12, 6))
sns.heatmap(heatmap_data, annot=True, cmap='Reds', fmt='.2f', linewidths=.5)
plt.title('CO2 Emissions Heatmap for Material Companies')
plt.show()

# %%
heatmap_data = windows_companies_list[['Company Name', 'CO2Emissions(MetricTons)']].set_index('Company Name')

plt.figure(figsize=(12, 6))
sns.heatmap(heatmap_data, annot=True, cmap='Reds', fmt='.2f', linewidths=.5)
plt.title('CO2 Emissions Heatmap for Windows Companies')
plt.show()

# %%
heatmap_data = textile_companies_list[['Company Name', 'CO2Emissions(MetricTons)']].set_index('Company Name')

plt.figure(figsize=(12, 6))
sns.heatmap(heatmap_data, annot=True, cmap='Reds', fmt='.2f', linewidths=.5)
plt.title('CO2 Emissions Heatmap for Textile Companies')
plt.show()

# %%
heatmap_data = paint_companies_list[['Company Name', 'CO2Emissions(MetricTons)']].set_index('Company Name')

plt.figure(figsize=(12, 6))
sns.heatmap(heatmap_data, annot=True, cmap='Reds', fmt='.2f', linewidths=.5)
plt.title('CO2 Emissions Heatmap for Paint Companies')
plt.show()

# %%
heatmap_data = electronics_companies_list[['Company Name', 'CO2Emissions(MetricTons)']].set_index('Company Name')

plt.figure(figsize=(12, 6))
sns.heatmap(heatmap_data, annot=True, cmap='Reds', fmt='.2f', linewidths=.5)
plt.title('CO2 Emissions Heatmap for Electronics Companies')
plt.show()

# %%
#Steel
steel_companies_list_environmental_friendly = steel_companies_list[
    (steel_companies_list['CO2Emissions(MetricTons)'] < 1.5) &
    (steel_companies_list['WasteGeneration(Tons in kg)'] < 40) &
    (steel_companies_list['TotalSum'] < steel_companies_list['TotalSum'].quantile(0.25))
]

#Copper
copper_companies_list_environmental_friendly = copper_companies_list[
    (copper_companies_list['CO2Emissions(MetricTons)'] < 5.5) &
    (copper_companies_list['WasteGeneration(PerTon in kg)'] < 35) &
    (copper_companies_list['TotalSum'] < copper_companies_list['TotalSum'].quantile(0.40))
]

#Aluminium
aluminium_companies_list_environmental_friendly = aluminium_companies_list[
    (aluminium_companies_list['CO2Emissions(MetricTons)'] < 5) &
    (aluminium_companies_list['WasteGeneration(PerTon in kg)'] < 30) &
    (aluminium_companies_list['TotalSum'] < aluminium_companies_list['TotalSum'].quantile(0.25))
]

#Rubber
rubber_companies_list_environmental_friendly = rubber_companies_list[
    (rubber_companies_list['CO2Emissions(MetricTons)'] < 20) &
    (rubber_companies_list['WasteGeneration(Tons in kg)'] < 16) &
    (rubber_companies_list['TotalSum'] < rubber_companies_list['TotalSum'].quantile(0.20))
]

#Plastic
plastic_companies_list_environmental_friendly = plastic_companies_list[
    (plastic_companies_list['CO2Emissions(MetricTons)'] < 4) &
    (plastic_companies_list['WasteGeneration(Tons in kg)'] < 25) &
    (plastic_companies_list['TotalSum'] < plastic_companies_list['TotalSum'].quantile(0.25))
]

#Polymer
polymer_companies_list_environmental_friendly = polymer_companies_list[
    (polymer_companies_list['CO2Emissions(MetricTons)'] < 4.5) &
    (polymer_companies_list['WasteGeneration(PerTon in kg)'] < 30) &
    (polymer_companies_list['TotalSum'] < polymer_companies_list['TotalSum'].quantile(0.1))
]

#Bolts
bolts_companies_list_environmental_friendly = bolts_companies_list[
    (bolts_companies_list['CO2Emissions(MetricTons)'] < 4) &
    (bolts_companies_list['WasteGeneration(PerTon in kg)'] < 30) &
    (bolts_companies_list['TotalSum'] < bolts_companies_list['TotalSum'].quantile(0.35))
]

#Material
material_companies_list_environmental_friendly = material_companies_list[
    (material_companies_list['CO2Emissions(MetricTons)'] < 2.5) &
    (material_companies_list['WasteGeneration(PerTon in kg)'] < 50) &
    (material_companies_list['TotalSum'] < material_companies_list['TotalSum'].quantile(0.25))
]

#Windows
windows_companies_list_environmental_friendly = windows_companies_list[
    (windows_companies_list['CO2Emissions(MetricTons)'] < 3.3) &
    (windows_companies_list['WasteGeneration(Tons in kg)'] < 15) &
    (windows_companies_list['TotalSum'] < windows_companies_list['TotalSum'].quantile(0.35))
]

#Textile
textile_companies_list_environmental_friendly = textile_companies_list[
    (textile_companies_list['CO2Emissions(MetricTons)'] < 3.3) &
    (textile_companies_list['WasteGeneration(PerTon in kg)'] < 15) &
    (textile_companies_list['TotalSum'] < textile_companies_list['TotalSum'].quantile(0.10))
]

#Paint
paint_companies_list_environmental_friendly = paint_companies_list[
    (paint_companies_list['CO2Emissions(MetricTons)'] < 1.5) &
    (paint_companies_list['WasteGeneration(PerTon in kg)'] < 7) &
    (paint_companies_list['TotalSum'] < paint_companies_list['TotalSum'].quantile(0.25))
]

#Electronics
electronics_companies_list_environmental_friendly = electronics_companies_list[
    (electronics_companies_list['CO2Emissions(MetricTons)'] < 2.4) &
    (electronics_companies_list['WasteGeneration(PerTon in kg)'] < 16) &
    (electronics_companies_list['TotalSum'] < electronics_companies_list['TotalSum'].quantile(0.25))
]

steel_companies_list_environmental_friendly_list = steel_companies_list_environmental_friendly.loc[steel_companies_list_environmental_friendly['TotalSum'].idxmin()]
copper_companies_list_environmental_friendly_list = copper_companies_list_environmental_friendly.loc[copper_companies_list_environmental_friendly['TotalSum'].idxmin()]
aluminium_companies_list_environmental_friendly_list = aluminium_companies_list_environmental_friendly.loc[aluminium_companies_list_environmental_friendly['TotalSum'].idxmin()]
rubber_companies_list_environmental_friendly_list = rubber_companies_list_environmental_friendly.loc[rubber_companies_list_environmental_friendly['TotalSum'].idxmin()]
plastic_companies_list_environmental_friendly_list = plastic_companies_list_environmental_friendly.loc[plastic_companies_list_environmental_friendly['TotalSum'].idxmin()]
polymer_companies_list_environmental_friendly_list = polymer_companies_list_environmental_friendly.loc[polymer_companies_list_environmental_friendly['TotalSum'].idxmin()]
bolts_companies_list_environmental_friendly_list = bolts_companies_list_environmental_friendly.loc[bolts_companies_list_environmental_friendly['TotalSum'].idxmin()]
material_companies_list_environmental_friendly_list = material_companies_list_environmental_friendly.loc[material_companies_list_environmental_friendly['TotalSum'].idxmin()]
windows_companies_list_environmental_friendly_list = windows_companies_list_environmental_friendly.loc[windows_companies_list_environmental_friendly['TotalSum'].idxmin()]
textile_companies_list_environmental_friendly_list = textile_companies_list_environmental_friendly.loc[textile_companies_list_environmental_friendly['TotalSum'].idxmin()]
paint_companies_list_environmental_friendly_list = paint_companies_list_environmental_friendly.loc[paint_companies_list_environmental_friendly['TotalSum'].idxmin()]
electronics_companies_list_environmental_friendly_list = electronics_companies_list_environmental_friendly.loc[electronics_companies_list_environmental_friendly['TotalSum'].idxmin()]

print("Steel Company which are environmental friendly and also cost effective:")
print(steel_companies_list_environmental_friendly_list)

print("\nCopper Company which are environmental friendly and also cost effective:")
print(copper_companies_list_environmental_friendly_list)

print("\nAluminium Company which are environmental friendly and also cost effective:")
print(aluminium_companies_list_environmental_friendly_list)

print("\nRubber Company which are environmental friendly and also cost effective:")
print(rubber_companies_list_environmental_friendly_list)

print("\nPlastic Company which are environmental friendly and also cost effective:")
print(plastic_companies_list_environmental_friendly_list)

print("\nPolymer Company which are environmental friendly and also cost effective:")
print(polymer_companies_list_environmental_friendly_list)

print("\nBolts Company which are environmental friendly and also cost effective:")
print(bolts_companies_list_environmental_friendly_list)

print("\nMaterial Company which are environmental friendly and also cost effective:")
print(material_companies_list_environmental_friendly_list)

print("\nWindows Company which are environmental friendly and also cost effective:")
print(windows_companies_list_environmental_friendly_list)

print("\nTextile Company which are environmental friendly and also cost effective:")
print(textile_companies_list_environmental_friendly_list)

print("\nPaint Company which are environmental friendly and also cost effective:")
print(paint_companies_list_environmental_friendly_list)

print("\nElectronics Company which are environmental friendly and also cost effective:")
print(electronics_companies_list_environmental_friendly_list)
# Out:
# Steel Company which are environmental friendly and also cost effective:
# Company ID                                               3
# Company Name                   Sustainable Steel Solutions
# Location                                         Bangalore
# EnergyUsage(MegawattHours)                          180000
# EnergySource                                         Solar
# WasteGeneration(Tons in kg)                             33
# CO2Emissions(MetricTons)                               1.2
# CostOfSteel(USDPerTon)                                 850
# Distance                                              12.0
# TransportationCost                                    19.2
# TotalSum                                             994.0
# Name: 2, dtype: object
#
# Copper Company which are environmental friendly and also cost effective:
# Company ID                                            3
# Company Name                     EcoMetals Copper India
# ...

# %%
combined_df = pd.concat([
    steel_companies_list_environmental_friendly,
    copper_companies_list_environmental_friendly,
    aluminium_companies_list_environmental_friendly,
    rubber_companies_list_environmental_friendly,
    plastic_companies_list_environmental_friendly,
    polymer_companies_list_environmental_friendly,
    bolts_companies_list_environmental_friendly,
    material_companies_list_environmental_friendly,
    windows_companies_list_environmental_friendly,
    textile_companies_list_environmental_friendly,
    paint_companies_list_environmental_friendly,
    electronics_companies_list_environmental_friendly
], ignore_index=True)

co2_emissions_column = combined_df['CO2Emissions(MetricTons)'].sum()

waste_generation_column = combined_df['WasteGeneration(PerTon in kg)'].sum()
waste_generation_column1 = combined_df['WasteGeneration(Tons in kg)'].sum()
waste_generation_total = waste_generation_column + waste_generation_column1

print('Total CO2 emission we will be generating for getting 1 Ton of raw material of each component is approximately:', co2_emissions_column, 'Metric Ton')
print('Total Waste Generation that occurs for getting 1 Ton of raw material of each component is approximately:', waste_generation_total, 'kg')
# Out:
# Total CO2 emission we will be generating for getting 1 Ton of raw material of each component is approximately: 43.7 Metric Ton
# Total Waste Generation that occurs for getting 1 Ton of raw material of each component is approximately: 213.1 kg

# %%
#Steel
steel_total_costs = []
steel_carbon_generate = []
steel_waste_generate = []

for steel_required in manufacturing_car_list['Steel Required (in kg):']:
    steel_cost = (steel_required/1000)*steel_companies_list_environmental_friendly['TotalSum'].item()
    steel_carbon = (steel_required/1000)*steel_companies_list_environmental_friendly['CO2Emissions(MetricTons)'].item()
    steel_waste = (steel_required/1000)*steel_companies_list_environmental_friendly['WasteGeneration(Tons in kg)'].item()
    steel_total_costs.append(steel_cost)
    steel_carbon_generate.append(steel_carbon)
    steel_waste_generate.append(steel_waste)

manufacturing_car_list['Steel Cost'] = steel_total_costs
manufacturing_car_list['Steel Carbon Emission (Metric Ton)'] = steel_carbon_generate
manufacturing_car_list['Steel Waste Generation (per kg)'] = steel_waste_generate

#Copper
copper_total_costs = []
copper_carbon_generate = []
copper_waste_generate = []

for copper_required in manufacturing_car_list['Copper Required (in kg):']:
    copper_cost = (copper_required/1000)*copper_companies_list_environmental_friendly['TotalSum'].item()
    copper_carbon = (copper_required/1000)*copper_companies_list_environmental_friendly['CO2Emissions(MetricTons)'].item()
    copper_waste = (copper_required/1000)*copper_companies_list_environmental_friendly['WasteGeneration(PerTon in kg)'].item()
    copper_total_costs.append(copper_cost)
    copper_carbon_generate.append(copper_carbon)
    copper_waste_generate.append(copper_waste)

manufacturing_car_list['Copper Cost'] = copper_total_costs
manufacturing_car_list['Copper Carbon Emission (Metric Ton)'] = copper_carbon_generate
manufacturing_car_list['Copper Waste Generation (per kg)'] = copper_waste_generate

#Aluminium
aluminium_total_costs = []
aluminium_carbon_generate = []
aluminium_waste_generate = []

for aluminium_required in manufacturing_car_list['Aluminium Required (in kg):']:
    aluminium_cost = (aluminium_required/1000)*aluminium_companies_list_environmental_friendly['TotalSum'].item()
    aluminium_carbon = (aluminium_required/1000)*aluminium_companies_list_environmental_friendly['CO2Emissions(MetricTons)'].item()
    aluminium_waste = (aluminium_required/1000)*aluminium_companies_list_environmental_friendly['WasteGeneration(PerTon in kg)'].item()
    aluminium_total_costs.append(aluminium_cost)
    aluminium_carbon_generate.append(aluminium_carbon)
    aluminium_waste_generate.append(aluminium_waste)

manufacturing_car_list['Aluminium Cost'] = aluminium_total_costs
manufacturing_car_list['Aluminium Carbon Emission (Metric Ton)'] = aluminium_carbon_generate
manufacturing_car_list['Aluminium Waste Generation (per kg)'] = aluminium_waste_generate

#Paint
paint_total_costs = []
paint_carbon_generate = []
paint_waste_generate = []

for paint_required in manufacturing_car_list['Paint Required (in kg):']:
    paint_cost = (paint_required/1000)*paint_companies_list_environmental_friendly['TotalSum'].item()
    paint_carbon = (paint_required/1000)*paint_companies_list_environmental_friendly['CO2Emissions(MetricTons)'].item()
    paint_waste = (paint_required/1000)*paint_companies_list_environmental_friendly['WasteGeneration(PerTon in kg)'].item()
    paint_total_costs.append(paint_cost)
    paint_carbon_generate.append(paint_carbon)
    paint_waste_generate.append(paint_waste)

manufacturing_car_list['Paint Cost'] = paint_total_costs
manufacturing_car_list['Paint Carbon Emission (Metric Ton)'] = paint_carbon_generate
manufacturing_car_list['Paint Waste Generation (per kg)'] = paint_waste_generate

#Bolts
bolts_total_costs = []
bolts_carbon_generate = []
bolts_waste_generate = []

for bolts_required in manufacturing_car_list['Bolts Required (in kg):']:
    bolts_cost = (bolts_required/1000)*bolts_companies_list_environmental_friendly['TotalSum'].item()
    bolts_carbon = (bolts_required/1000)*bolts_companies_list_environmental_friendly['CO2Emissions(MetricTons)'].item()
    bolts_waste = (bolts_required/1000)*bolts_companies_list_environmental_friendly['WasteGeneration(PerTon in kg)'].item()
    bolts_total_costs.append(bolts_cost)
    bolts_carbon_generate.append(bolts_carbon)
    bolts_waste_generate.append(bolts_waste)

manufacturing_car_list['Bolts Cost'] =bolts_total_costs
manufacturing_car_list['Bolts Carbon Emission (Metric Ton)'] = bolts_carbon_generate
manufacturing_car_list['Bolts Waste Generation (per kg)'] = bolts_waste_generate

#Plastic
plastic_total_costs = []
plastic_carbon_generate = []
plastic_waste_generate = []

for plastic_required in manufacturing_car_list['Plastic Required (in kg):']:
    plastic_cost = (plastic_required/1000)*plastic_companies_list_environmental_friendly['TotalSum'].item()
    plastic_carbon = (plastic_required/1000)*plastic_companies_list_environmental_friendly['CO2Emissions(MetricTons)'].item()
    plastic_waste = (plastic_required/1000)*plastic_companies_list_environmental_friendly['WasteGeneration(Tons in kg)'].item()
    plastic_total_costs.append(plastic_cost)
    plastic_carbon_generate.append(plastic_carbon)
    plastic_waste_generate.append(plastic_waste)

manufacturing_car_list['Plastic Cost'] = plastic_total_costs
manufacturing_car_list['Plastic Carbon Emission (Metric Ton)'] = plastic_carbon_generate
manufacturing_car_list['Plastic Waste Generation (per kg)'] = plastic_waste_generate

#Polymer
polymer_total_costs = []
polymer_carbon_generate = []
polymer_waste_generate = []

for polymer_required in manufacturing_car_list['Polymer Required (in kg):']:
    polymer_cost = (polymer_required/1000)*polymer_companies_list_environmental_friendly['TotalSum'].item()
    polymer_carbon = (polymer_required/1000)*polymer_companies_list_environmental_friendly['CO2Emissions(MetricTons)'].item()
    polymer_waste = (polymer_required/1000)*polymer_companies_list_environmental_friendly['WasteGeneration(PerTon in kg)'].item()
    polymer_total_costs.append(polymer_cost)
    polymer_carbon_generate.append(polymer_carbon)
    polymer_waste_generate.append(polymer_waste)

manufacturing_car_list['Polymer Cost'] = polymer_total_costs
manufacturing_car_list['Polymer Carbon Emission (Metric Ton)'] = polymer_carbon_generate
manufacturing_car_list['Polymer Waste Generation (per kg)'] = polymer_waste_generate

#Textile
textile_total_costs = []
textile_carbon_generate = []
textile_waste_generate = []

for textile_required in manufacturing_car_list['Textile Required (in kg):']:
    textile_cost = (textile_required/1000)*textile_companies_list_environmental_friendly['TotalSum'].item()
    textile_carbon = (textile_required/1000)*textile_companies_list_environmental_friendly['CO2Emissions(MetricTons)'].item()
    textile_waste = (textile_required/1000)*textile_companies_list_environmental_friendly['WasteGeneration(PerTon in kg)'].item()
    textile_total_costs.append(textile_cost)
    textile_carbon_generate.append(textile_carbon)
    textile_waste_generate.append(textile_waste)

manufacturing_car_list['Textile Cost'] = textile_total_costs
manufacturing_car_list['Textile Carbon Emission (Metric Ton)'] = textile_carbon_generate
manufacturing_car_list['Textile Waste Generation (per kg)'] = textile_waste_generate

#Material
material_total_costs = []
material_carbon_generate = []
material_waste_generate = []

for material_required in manufacturing_car_list['Material Required (in kg):']:
    material_cost = (material_required/1000)*material_companies_list_environmental_friendly['TotalSum'].item()
    material_carbon = (material_required/1000)*material_companies_list_environmental_friendly['CO2Emissions(MetricTons)'].item()
    material_waste = (material_required/1000)*material_companies_list_environmental_friendly['WasteGeneration(PerTon in kg)'].item()
    material_total_costs.append(material_cost)
    material_carbon_generate.append(material_carbon)
    material_waste_generate.append(material_waste)

manufacturing_car_list['Material Cost'] = material_total_costs
manufacturing_car_list['Material Carbon Emission (Metric Ton)'] = material_carbon_generate
manufacturing_car_list['Material Waste Generation (per kg)'] = material_waste_generate

#Electronics
electronics_total_costs = []
electronics_carbon_generate = []
electronics_waste_generate = []

for electronics_required in manufacturing_car_list['Electronics Required (in kg):']:
    electronics_cost = (electronics_required/1000)*electronics_companies_list_environmental_friendly['TotalSum'].item()
    electronics_carbon = (electronics_required/1000)*electronics_companies_list_environmental_friendly['CO2Emissions(MetricTons)'].item()
    electronics_waste = (electronics_required/1000)*electronics_companies_list_environmental_friendly['WasteGeneration(PerTon in kg)'].item()
    electronics_total_costs.append(electronics_cost)
    electronics_carbon_generate.append(electronics_carbon)
    electronics_waste_generate.append(electronics_waste)

manufacturing_car_list['Electronics Cost'] = electronics_total_costs
manufacturing_car_list['Electronics Carbon Emission (Metric Ton)'] = electronics_carbon_generate
manufacturing_car_list['Electronics Waste Generation (per kg)'] = electronics_waste_generate

#Rubber
rubber_total_costs = []
rubber_carbon_generate = []
rubber_waste_generate = []

for rubber_required in manufacturing_car_list['Rubber Required (in kg):']:
    rubber_cost = (rubber_required/1000)*rubber_companies_list_environmental_friendly['TotalSum'].item()
    rubber_carbon = (rubber_required/1000)*rubber_companies_list_environmental_friendly['CO2Emissions(MetricTons)'].item()
    rubber_waste = (rubber_required/1000)*rubber_companies_list_environmental_friendly['WasteGeneration(Tons in kg)'].item()
    rubber_total_costs.append(rubber_cost)
    rubber_carbon_generate.append(rubber_carbon)
    rubber_waste_generate.append(rubber_waste)

manufacturing_car_list['Rubber Cost'] = rubber_total_costs
manufacturing_car_list['Rubber Carbon Emission (Metric Ton)'] = rubber_carbon_generate
manufacturing_car_list['Rubber Waste Generation (per kg)'] = rubber_waste_generate

#Windows
windows_total_costs = []
windows_carbon_generate = []
windows_waste_generate = []

for windows_required in manufacturing_car_list['Window Material Required (in kg):']:
    windows_cost = (windows_required/1000)*windows_companies_list_environmental_friendly['TotalSum'].item()
    windows_carbon = (windows_required/1000)*windows_companies_list_environmental_friendly['CO2Emissions(MetricTons)'].item()
    windows_waste = (windows_required/1000)*windows_companies_list_environmental_friendly['WasteGeneration(Tons in kg)'].item()
    windows_total_costs.append(windows_cost)
    windows_carbon_generate.append(windows_carbon)
    windows_waste_generate.append(windows_waste)

manufacturing_car_list['Windows Cost'] = windows_total_costs
manufacturing_car_list['Windows Carbon Emission (Metric Ton)'] = windows_carbon_generate
manufacturing_car_list['Windows Waste Generation (per kg)'] = windows_waste_generate

# %%
manufacturing_car_list['Carbon Emission Total'] = (
    manufacturing_car_list['CO2Emissions(MetricTons)'] +
    manufacturing_car_list['Bolts Carbon Emission (Metric Ton)'] +
    manufacturing_car_list['Copper Carbon Emission (Metric Ton)'] +
    manufacturing_car_list['Windows Carbon Emission (Metric Ton)'] +
    manufacturing_car_list['Rubber Carbon Emission (Metric Ton)'] +
    manufacturing_car_list['Aluminium Carbon Emission (Metric Ton)'] +
    manufacturing_car_list['Steel Carbon Emission (Metric Ton)'] +
    manufacturing_car_list['Textile Carbon Emission (Metric Ton)'] +
    manufacturing_car_list['Electronics Carbon Emission (Metric Ton)'] +
    manufacturing_car_list['Material Carbon Emission (Metric Ton)'] +
    manufacturing_car_list['Plastic Carbon Emission (Metric Ton)'] +
    manufacturing_car_list['Paint Carbon Emission (Metric Ton)'] +
    manufacturing_car_list['Polymer Carbon Emission (Metric Ton)']
)

manufacturing_car_list['Waste Generation Total'] = (
    manufacturing_car_list['WasteGeneration(PerTon in kg)'] +
    manufacturing_car_list['Bolts Waste Generation (per kg)'] +
    manufacturing_car_list['Copper Waste Generation (per kg)'] +
    manufacturing_car_list['Windows Waste Generation (per kg)'] +
    manufacturing_car_list['Rubber Waste Generation (per kg)'] +
    manufacturing_car_list['Aluminium Waste Generation (per kg)'] +
    manufacturing_car_list['Steel Waste Generation (per kg)'] +
    manufacturing_car_list['Textile Waste Generation (per kg)'] +
    manufacturing_car_list['Electronics Waste Generation (per kg)'] +
    manufacturing_car_list['Material Waste Generation (per kg)'] +
    manufacturing_car_list['Plastic Waste Generation (per kg)'] +
    manufacturing_car_list['Paint Waste Generation (per kg)'] +
    manufacturing_car_list['Polymer Waste Generation (per kg)']
)

manufacturing_car_list['Manufacturing Cost'] = (
    manufacturing_car_list['CostOfAssembling(USDPerCar)'] +
    manufacturing_car_list['Copper Cost'] +
    manufacturing_car_list['Windows Cost'] +
    manufacturing_car_list['Rubber Cost'] +
    manufacturing_car_list['Aluminium Cost'] +
    manufacturing_car_list['Steel Cost'] +
    manufacturing_car_list['Textile Cost'] +
    manufacturing_car_list['Electronics Cost'] +
    manufacturing_car_list['Bolts Cost'] +
    manufacturing_car_list['Material Cost'] +
    manufacturing_car_list['Plastic Cost'] +
    manufacturing_car_list['Paint Cost'] +
    manufacturing_car_list['Polymer Cost']
)

# %%
manufacturing_car_list.drop(['Steel Cost', 'Steel Carbon Emission (Metric Ton)', 'Steel Waste Generation (per kg)'], axis=1, inplace=True)
manufacturing_car_list.drop(['Copper Cost', 'Copper Carbon Emission (Metric Ton)', 'Copper Waste Generation (per kg)'], axis=1, inplace=True)
manufacturing_car_list.drop(['Aluminium Cost', 'Aluminium Carbon Emission (Metric Ton)', 'Aluminium Waste Generation (per kg)'], axis=1, inplace=True)
manufacturing_car_list.drop(['Paint Cost', 'Paint Carbon Emission (Metric Ton)', 'Paint Waste Generation (per kg)'], axis=1, inplace=True)
manufacturing_car_list.drop(['Bolts Cost', 'Bolts Carbon Emission (Metric Ton)', 'Bolts Waste Generation (per kg)'], axis=1, inplace=True)
manufacturing_car_list.drop(['Plastic Cost', 'Plastic Carbon Emission (Metric Ton)', 'Plastic Waste Generation (per kg)'], axis=1, inplace=True)
manufacturing_car_list.drop(['Polymer Cost', 'Polymer Carbon Emission (Metric Ton)', 'Polymer Waste Generation (per kg)'], axis=1, inplace=True)
manufacturing_car_list.drop(['Textile Cost', 'Textile Carbon Emission (Metric Ton)', 'Textile Waste Generation (per kg)'], axis=1, inplace=True)
manufacturing_car_list.drop(['Material Cost', 'Material Carbon Emission (Metric Ton)', 'Material Waste Generation (per kg)'], axis=1, inplace=True)
manufacturing_car_list.drop(['Electronics Cost', 'Electronics Carbon Emission (Metric Ton)', 'Electronics Waste Generation (per kg)'], axis=1, inplace=True)
manufacturing_car_list.drop(['Rubber Cost', 'Rubber Carbon Emission (Metric Ton)', 'Rubber Waste Generation (per kg)'], axis=1, inplace=True)
manufacturing_car_list.drop(['Windows Cost', 'Windows Carbon Emission (Metric Ton)', 'Windows Waste Generation (per kg)'], axis=1, inplace=True)

# %%
manufacturing_car_list['Manufacturing Cost Total'] = manufacturing_car_list['Manufacturing Cost'] + (manufacturing_car_list['CO2Emissions(MetricTons)']*carbon_tax_per_metric_ton) + (manufacturing_car_list['WasteGeneration(PerTon in kg)']*waste_tax_per_kg)
